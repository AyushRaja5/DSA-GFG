# %%
import numpy as np
import cv2
kernelSize=21

# %%
parameter1=20
parameter2 = 60
intApertureSize = 1

# %%
cap = cv2.VideoCapture(0)

while(1):
    ref,frames = cap.read()
    #frames = cv2.GaussianBlur(frames,(kernelSize,kernelSize),0,0)
    #frames = cv2.Canny(frames,parameter1,parameter2,intApertureSize)
    #frames = cv2.Laplacian(frames,cv2.CV_64F)
    #frames = cv2.Sobel(frames,cv2.CV_64F,1,0,ksize=kernelSize)
    #frames = cv2.Sobel(frames,cv2.CV_64F,0,1,ksize=kernelSize)
    frames = cv2.Sobel(frames,cv2.CV_64F,3,7,ksize=kernelSize)
    cv2.imshow('Laplacian',frames)
    if cv2.waitKey(1) & 0xFF == ord('q'): # press q to quit
        break
    # When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
